# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\michael1005\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\michael1005\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 614

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f7ea02b17bc5239a2995464f061426c6

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 49.17,
#   'feels_like': 34.52,
#   'temp_min': 46,
#   'temp_max': 52,
#   'pressure': 1009,
#   'humidity': 23},
#  'visibility': 16093,
#  'wind': {'speed': 16.11, 'deg': 290, 'gust': 29.97},
#  'clouds': {'all': 40},
#  'dt': 1586986659,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1586944936,
#   'sunset': 1586993134},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        #try-except for snow
        try:
            city_snow = city_weather["snow"]["1h"]
        except(KeyError):
            city_snow = 0
        #tr-except for rain
        try:
            city_rain = city_weather["rain"]["1h"] 
        except(KeyError):
            city_rain = 0
        
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_desc,
                            "Rain inches (last 3 hrs)": city_rain,
                            "Snow inches (last 3 hrs)": city_snow,
                            "Country": city_country,
                            "Date": city_date})
    # if a KeyError occurs
    except:
        print("City not found. Skipping...")
        pass
    
        

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 1 | bagdarin
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | yinchuan
# Processing Record 11 of Set 1 | tessalit
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | vila do maio
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | harper
# Processing Record 18 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 1 | that phanom
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | asau
# Processing Record 22 of Set 1 | southbridge
# Processing Record 23 of Set 1 | madang
# Processing Record 24 of Set 1 | zhuhai
# Processing Record 25 of Set 1 | farafangana
# Processing Record 26 of Set 1 | shimoda
# Processing Record 27 of Set 1 | port lincoln
# Processing Record 28 of Set 1 | puerto escondido
# Processing Record 29 of Set 1 | tabialan
# City not found. Skipping...
# Processing Record 30 of Set 1 | ereymentau
# Processing Record 31 of Set 1 | pangkalanbuun
# Processing Record 32 of Set 1 | nuuk
# Processing Record 33 of Set 1 | keetmanshoop
# Processing Record 34 of Set 1 | mendeleyevo
# Processing Record 35 of Set 1 | kodinsk
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | deputatskiy
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | bodaybo
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | bhimunipatnam
# Processing Record 49 of Set 1 | eureka
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | mahenge
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | ialibu
# Processing Record 5 of Set 2 | amapa
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | husavik
# Processing Record 9 of Set 2 | ocampo
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | faya
# Processing Record 16 of Set 2 | waipawa
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | san pedro
# Processing Record 19 of Set 2 | kenai
# Processing Record 20 of Set 2 | ewa beach
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | itaituba
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | nekrasovskoye
# Processing Record 25 of Set 2 | fort morgan
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | seymchan
# Processing Record 31 of Set 2 | aktau
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | karratha
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | chase
# Processing Record 41 of Set 2 | cartagena
# Processing Record 42 of Set 2 | virginia beach
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 2 | terenos
# Processing Record 47 of Set 2 | loandjili
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | nova era
# Processing Record 1 of Set 3 | bud
# Processing Record 2 of Set 3 | kiunga
# Processing Record 3 of Set 3 | dixon
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | najran
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | whitehorse
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | lasa
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | port hedland
# Processing Record 13 of Set 3 | west bay
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | tommot
# Processing Record 18 of Set 3 | tual
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | horsens
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | kaoma
# Processing Record 23 of Set 3 | kerchevskiy
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | itarema
# Processing Record 26 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 27 of Set 3 | montepuez
# Processing Record 28 of Set 3 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 3 | bahia blanca
# Processing Record 30 of Set 3 | vao
# Processing Record 31 of Set 3 | talagang
# Processing Record 32 of Set 3 | naze
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | south venice
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | aracruz
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | barrow
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | mar del plata
# Processing Record 47 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | cartagena del chaira
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | yashan
# Processing Record 2 of Set 4 | marzuq
# Processing Record 3 of Set 4 | bambanglipuro
# Processing Record 4 of Set 4 | hofn
# Processing Record 5 of Set 4 | luderitz
# Processing Record 6 of Set 4 | adrar
# Processing Record 7 of Set 4 | liverpool
# Processing Record 8 of Set 4 | takoradi
# Processing Record 9 of Set 4 | kungurtug
# Processing Record 10 of Set 4 | prescott
# Processing Record 11 of Set 4 | egvekinot
# Processing Record 12 of Set 4 | ayan
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | xingcheng
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | portland
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 4 | pavlodar
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | pareora
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | bambous virieux
# Processing Record 24 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | male
# Processing Record 26 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | nhulunbuy
# Processing Record 29 of Set 4 | japura
# Processing Record 30 of Set 4 | rensvik
# Processing Record 31 of Set 4 | cap malheureux
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 4 | cayenne
# Processing Record 35 of Set 4 | clonakilty
# Processing Record 36 of Set 4 | lima
# Processing Record 37 of Set 4 | staraya russa
# Processing Record 38 of Set 4 | salalah
# Processing Record 39 of Set 4 | inhambane
# Processing Record 40 of Set 4 | hamamatsu
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | shache
# Processing Record 43 of Set 4 | kavaratti
# Processing Record 44 of Set 4 | concordia
# Processing Record 45 of Set 4 | serabu
# Processing Record 46 of Set 4 | waddan
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | aquiraz
# Processing Record 50 of Set 4 | lewisporte
# Processing Record 1 of Set 5 | pierre
# Processing Record 2 of Set 5 | tasiilaq
# Processing Record 3 of Set 5 | conceicao das alagoas
# Processing Record 4 of Set 5 | aktash
# Processing Record 5 of Set 5 | myitkyina
# Processing Record 6 of Set 5 | aykhal
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | arman
# Processing Record 9 of Set 5 | avera
# Processing Record 10 of Set 5 | richards bay
# Processing Record 11 of Set 5 | srednekolymsk
# Processing Record 12 of Set 5 | plouzane
# Processing Record 13 of Set 5 | siraha
# Processing Record 14 of Set 5 | roseburg
# Processing Record 15 of Set 5 | matamoros
# Processing Record 16 of Set 5 | tara
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | san rafael del sur
# Processing Record 21 of Set 5 | oktyabrskoye
# Processing Record 22 of Set 5 | tabuk
# Processing Record 23 of Set 5 | asyut
# Processing Record 24 of Set 5 | mbandaka
# Processing Record 25 of Set 5 | vostok
# Processing Record 26 of Set 5 | fort nelson
# Processing Record 27 of Set 5 | kruisfontein
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | jumla
# Processing Record 30 of Set 5 | bonga
# Processing Record 31 of Set 5 | ojinaga
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 5 | ho
# City not found. Skipping...
# Processing Record 36 of Set 5 | pemangkat
# Processing Record 37 of Set 5 | kushmurun
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | bowen
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | pandan
# Processing Record 43 of Set 5 | trairi
# Processing Record 44 of Set 5 | cradock
# Processing Record 45 of Set 5 | haines junction
# Processing Record 46 of Set 5 | palmer
# Processing Record 47 of Set 5 | ketchikan
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | strezhevoy
# Processing Record 50 of Set 5 | guarapari
# Processing Record 1 of Set 6 | aripuana
# Processing Record 2 of Set 6 | prince rupert
# Processing Record 3 of Set 6 | langham
# Processing Record 4 of Set 6 | repalle
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | valence
# Processing Record 7 of Set 6 | carnduff
# Processing Record 8 of Set 6 | igarka
# Processing Record 9 of Set 6 | cockburn town
# Processing Record 10 of Set 6 | thongwa
# Processing Record 11 of Set 6 | ondangwa
# Processing Record 12 of Set 6 | sao jose da coroa grande
# Processing Record 13 of Set 6 | teya
# Processing Record 14 of Set 6 | cururupu
# Processing Record 15 of Set 6 | sinnamary
# Processing Record 16 of Set 6 | columbus
# Processing Record 17 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | vila velha
# Processing Record 20 of Set 6 | grootfontein
# Processing Record 21 of Set 6 | fort wellington
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | vestmanna
# Processing Record 24 of Set 6 | montrose
# Processing Record 25 of Set 6 | manokwari
# Processing Record 26 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 27 of Set 6 | lanzhou
# Processing Record 28 of Set 6 | dukat
# Processing Record 29 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 6 | tortoli
# Processing Record 31 of Set 6 | enid
# Processing Record 32 of Set 6 | mwembe
# Processing Record 33 of Set 6 | merauke
# Processing Record 34 of Set 6 | vysokogornyy
# Processing Record 35 of Set 6 | marialva
# Processing Record 36 of Set 6 | borogontsy
# Processing Record 37 of Set 6 | namwala
# Processing Record 38 of Set 6 | beringovskiy
# Processing Record 39 of Set 6 | high level
# Processing Record 40 of Set 6 | atambua
# Processing Record 41 of Set 6 | burica
# City not found. Skipping...
# Processing Record 42 of Set 6 | batangafo
# Processing Record 43 of Set 6 | carndonagh
# Processing Record 44 of Set 6 | labuhan
# Processing Record 45 of Set 6 | krasnyy chikoy
# Processing Record 46 of Set 6 | xuddur
# Processing Record 47 of Set 6 | kirakira
# Processing Record 48 of Set 6 | sovetskaya gavan
# Processing Record 49 of Set 6 | mahebourg
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | markova
# Processing Record 2 of Set 7 | manicore
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 7 | hapao
# Processing Record 6 of Set 7 | pangnirtung
# Processing Record 7 of Set 7 | paracuru
# Processing Record 8 of Set 7 | grand gaube
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | ngunguru
# Processing Record 11 of Set 7 | bontang
# Processing Record 12 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 7 | balykshi
# City not found. Skipping...
# Processing Record 14 of Set 7 | kendari
# Processing Record 15 of Set 7 | karimpur
# Processing Record 16 of Set 7 | rosetta
# Processing Record 17 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 7 | hobyo
# Processing Record 19 of Set 7 | vasteras
# Processing Record 20 of Set 7 | dongning
# Processing Record 21 of Set 7 | alencon
# Processing Record 22 of Set 7 | chumikan
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | constitucion
# Processing Record 25 of Set 7 | puerto ayora
# Processing Record 26 of Set 7 | north platte
# Processing Record 27 of Set 7 | ukiah
# Processing Record 28 of Set 7 | el paso
# Processing Record 29 of Set 7 | leshukonskoye
# Processing Record 30 of Set 7 | misratah
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | aldan
# Processing Record 33 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 7 | darnah
# Processing Record 35 of Set 7 | novyy urengoy
# Processing Record 36 of Set 7 | kathmandu
# Processing Record 37 of Set 7 | qostanay
# Processing Record 38 of Set 7 | mirabad
# Processing Record 39 of Set 7 | svetlyy
# Processing Record 40 of Set 7 | lata
# Processing Record 41 of Set 7 | orapa
# Processing Record 42 of Set 7 | dolores
# Processing Record 43 of Set 7 | cepu
# Processing Record 44 of Set 7 | kon tum
# Processing Record 45 of Set 7 | dingle
# Processing Record 46 of Set 7 | snasa
# Processing Record 47 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 7 | dobroye
# Processing Record 49 of Set 7 | port augusta
# Processing Record 50 of Set 7 | guerrero negro
# Processing Record 1 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 8 | puertollano
# Processing Record 3 of Set 8 | cabedelo
# Processing Record 4 of Set 8 | pitanga
# Processing Record 5 of Set 8 | hvolsvollur
# Processing Record 6 of Set 8 | moyale
# Processing Record 7 of Set 8 | saint-joseph
# Processing Record 8 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | gigmoto
# Processing Record 11 of Set 8 | wanxian
# Processing Record 12 of Set 8 | sisimiut
# Processing Record 13 of Set 8 | amahai
# Processing Record 14 of Set 8 | taltal
# Processing Record 15 of Set 8 | kargasok
# Processing Record 16 of Set 8 | lompoc
# Processing Record 17 of Set 8 | rawson
# Processing Record 18 of Set 8 | kumi
# Processing Record 19 of Set 8 | drogenbos
# Processing Record 20 of Set 8 | honiara
# Processing Record 21 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 8 | carberry
# Processing Record 23 of Set 8 | terney
# Processing Record 24 of Set 8 | zyryanka
# Processing Record 25 of Set 8 | maningrida
# Processing Record 26 of Set 8 | sainte-suzanne
# Processing Record 27 of Set 8 | henderson
# Processing Record 28 of Set 8 | cairns
# Processing Record 29 of Set 8 | raubling
# Processing Record 30 of Set 8 | hamilton
# Processing Record 31 of Set 8 | flin flon
# Processing Record 32 of Set 8 | cabo san lucas
# Processing Record 33 of Set 8 | rovaniemi
# Processing Record 34 of Set 8 | kamenka
# Processing Record 35 of Set 8 | kodiak
# Processing Record 36 of Set 8 | narsaq
# Processing Record 37 of Set 8 | sokolo
# Processing Record 38 of Set 8 | polunochnoye
# Processing Record 39 of Set 8 | moindou
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | roebourne
# Processing Record 42 of Set 8 | rundu
# Processing Record 43 of Set 8 | nikolskoye
# Processing Record 44 of Set 8 | qena
# Processing Record 45 of Set 8 | sosnogorsk
# Processing Record 46 of Set 8 | los chiles
# Processing Record 47 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 8 | ucluelet
# Processing Record 49 of Set 8 | lichinga
# Processing Record 50 of Set 8 | sambava
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | atar
# Processing Record 3 of Set 9 | san patricio
# Processing Record 4 of Set 9 | murchison
# Processing Record 5 of Set 9 | berdigestyakh
# Processing Record 6 of Set 9 | batagay
# Processing Record 7 of Set 9 | lucapa
# Processing Record 8 of Set 9 | mapastepec
# Processing Record 9 of Set 9 | poum
# Processing Record 10 of Set 9 | vaitape
# Processing Record 11 of Set 9 | itabira
# Processing Record 12 of Set 9 | barcelos
# Processing Record 13 of Set 9 | korla
# Processing Record 14 of Set 9 | ridgecrest
# Processing Record 15 of Set 9 | shawnee
# Processing Record 16 of Set 9 | glyadyanskoye
# Processing Record 17 of Set 9 | ust-ishim
# Processing Record 18 of Set 9 | klaksvik
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | dauphin
# Processing Record 21 of Set 9 | natal
# Processing Record 22 of Set 9 | itupiranga
# Processing Record 23 of Set 9 | alice springs
# Processing Record 24 of Set 9 | arecibo
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | coquimbo
# Processing Record 27 of Set 9 | pauini
# Processing Record 28 of Set 9 | kumluca
# Processing Record 29 of Set 9 | sakakah
# Processing Record 30 of Set 9 | kalmunai
# Processing Record 31 of Set 9 | berlevag
# Processing Record 32 of Set 9 | solnechnyy
# Processing Record 33 of Set 9 | bandarbeyla
# Processing Record 34 of Set 9 | san juan
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | maceio
# Processing Record 37 of Set 9 | nicoya
# Processing Record 38 of Set 9 | ostrovnoy
# Processing Record 39 of Set 9 | krasnogorskoye
# Processing Record 40 of Set 9 | hami
# Processing Record 41 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 9 | bafq
# Processing Record 43 of Set 9 | havre-saint-pierre
# Processing Record 44 of Set 9 | jinchang
# Processing Record 45 of Set 9 | broken arrow
# Processing Record 46 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 9 | aksu
# Processing Record 48 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 9 | ipanguacu
# Processing Record 50 of Set 9 | tema
# Processing Record 1 of Set 10 | marrakesh
# Processing Record 2 of Set 10 | san ignacio
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 5 of Set 10 | zumarraga
# Processing Record 6 of Set 10 | tabas
# Processing Record 7 of Set 10 | mayo
# Processing Record 8 of Set 10 | padang
# Processing Record 9 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 10 | san quintin
# Processing Record 11 of Set 10 | kuzedeyevo
# Processing Record 12 of Set 10 | nanortalik
# Processing Record 13 of Set 10 | roches noires
# City not found. Skipping...
# Processing Record 14 of Set 10 | yenagoa
# Processing Record 15 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 10 | gilazi
# City not found. Skipping...
# Processing Record 17 of Set 10 | buraydah
# Processing Record 18 of Set 10 | lorengau
# Processing Record 19 of Set 10 | high rock
# Processing Record 20 of Set 10 | abay
# Processing Record 21 of Set 10 | lingao
# Processing Record 22 of Set 10 | turukhansk
# Processing Record 23 of Set 10 | altamira
# Processing Record 24 of Set 10 | hargeysa
# Processing Record 25 of Set 10 | nyrob
# Processing Record 26 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 10 | xichang
# Processing Record 28 of Set 10 | olga
# Processing Record 29 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 10 | tilichiki
# Processing Record 31 of Set 10 | gbarnga
# Processing Record 32 of Set 10 | tutoia
# Processing Record 33 of Set 10 | skibotn
# Processing Record 34 of Set 10 | yazman
# Processing Record 35 of Set 10 | kirensk
# Processing Record 36 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 37 of Set 10 | askiz
# Processing Record 38 of Set 10 | north bend
# Processing Record 39 of Set 10 | isla mujeres
# Processing Record 40 of Set 10 | george town
# Processing Record 41 of Set 10 | marang
# Processing Record 42 of Set 10 | pingshan
# Processing Record 43 of Set 10 | vinh
# Processing Record 44 of Set 10 | nabire
# Processing Record 45 of Set 10 | lang son
# Processing Record 46 of Set 10 | ranong
# Processing Record 47 of Set 10 | ellensburg
# Processing Record 48 of Set 10 | porosozero
# Processing Record 49 of Set 10 | puqi
# Processing Record 50 of Set 10 | kununurra
# Processing Record 1 of Set 11 | saint-augustin
# Processing Record 2 of Set 11 | tarakan
# Processing Record 3 of Set 11 | saint anthony
# Processing Record 4 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 5 of Set 11 | santa cruz del sur
# Processing Record 6 of Set 11 | yar-sale
# Processing Record 7 of Set 11 | mercedes
# Processing Record 8 of Set 11 | vila franca do campo
# Processing Record 9 of Set 11 | sebring
# Processing Record 10 of Set 11 | gobabis
# Processing Record 11 of Set 11 | saint-pierre
# Processing Record 12 of Set 11 | chingirlau
# Processing Record 13 of Set 11 | gat
# Processing Record 14 of Set 11 | kajaani
# Processing Record 15 of Set 11 | abu zabad
# Processing Record 16 of Set 11 | urumqi
# Processing Record 17 of Set 11 | flinders
# Processing Record 18 of Set 11 | sampit
# Processing Record 19 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 11 | vanino
# Processing Record 21 of Set 11 | san pedro de uraba
# Processing Record 22 of Set 11 | tura
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | laguna
# Processing Record 25 of Set 11 | san andres
# Processing Record 26 of Set 11 | waingapu
# Processing Record 27 of Set 11 | campanario
# Processing Record 28 of Set 11 | banda aceh
# Processing Record 29 of Set 11 | krasnoye
# Processing Record 30 of Set 11 | zykovo
# Processing Record 31 of Set 11 | angoche
# Processing Record 32 of Set 11 | louis trichardt
# Processing Record 33 of Set 11 | syasstroy
# Processing Record 34 of Set 11 | soyo
# Processing Record 35 of Set 11 | anloga
# Processing Record 36 of Set 11 | russell
# Processing Record 37 of Set 11 | roma
# Processing Record 38 of Set 11 | kaitangata
# Processing Record 39 of Set 11 | tanga
# Processing Record 40 of Set 11 | omboue
# Processing Record 41 of Set 11 | samfya
# Processing Record 42 of Set 11 | sale
# Processing Record 43 of Set 11 | ponca city
# Processing Record 44 of Set 11 | kaseda
# Processing Record 45 of Set 11 | yichun
# Processing Record 46 of Set 11 | lazaro cardenas
# Processing Record 47 of Set 11 | dzerzhinskoye
# Processing Record 48 of Set 11 | qasigiannguit
# Processing Record 49 of Set 11 | blackwater
# Processing Record 50 of Set 11 | tres lagoas
# Processing Record 1 of Set 12 | sinjah
# City not found. Skipping...
# Processing Record 2 of Set 12 | suba
# Processing Record 3 of Set 12 | tokur
# Processing Record 4 of Set 12 | zaysan
# Processing Record 5 of Set 12 | chara
# Processing Record 6 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 12 | dalvik
# Processing Record 8 of Set 12 | toksovo
# Processing Record 9 of Set 12 | pacaembu
# Processing Record 10 of Set 12 | nokaneng
# Processing Record 11 of Set 12 | thinadhoo
# Processing Record 12 of Set 12 | los algarrobos
# Processing Record 13 of Set 12 | quatre cocos
# Processing Record 14 of Set 12 | mizan teferi
# Processing Record 15 of Set 12 | lavrentiya
# Processing Record 16 of Set 12 | straubing
# Processing Record 17 of Set 12 | vallenar
# Processing Record 18 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 12 | grand-santi
# Processing Record 20 of Set 12 | muriwai beach
# Processing Record 21 of Set 12 | bonthe
# Processing Record 22 of Set 12 | fukue
# Processing Record 23 of Set 12 | sirjan
# Processing Record 24 of Set 12 | khani
# Processing Record 25 of Set 12 | khasan
# Processing Record 26 of Set 12 | taman
# Processing Record 27 of Set 12 | beloha
# Processing Record 28 of Set 12 | paka
# Processing Record 29 of Set 12 | novikovo
# Processing Record 30 of Set 12 | sawtell
# Processing Record 31 of Set 12 | amnat charoen
# Processing Record 32 of Set 12 | kharp
# Processing Record 33 of Set 12 | yerofey pavlovich
# Processing Record 34 of Set 12 | paamiut
# Processing Record 35 of Set 12 | voznesenskaya
# Processing Record 36 of Set 12 | wakkanai
# Processing Record 37 of Set 12 | dolinsk
# Processing Record 38 of Set 12 | udachnyy
# Processing Record 39 of Set 12 | otjiwarongo
# Processing Record 40 of Set 12 | burgeo
# Processing Record 41 of Set 12 | magistralnyy
# Processing Record 42 of Set 12 | menongue
# Processing Record 43 of Set 12 | mount isa
# Processing Record 44 of Set 12 | snezhnogorsk
# Processing Record 45 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 12 | ingham
# Processing Record 47 of Set 12 | codajas
# Processing Record 48 of Set 12 | sungaipenuh
# Processing Record 49 of Set 12 | carlsbad
# Processing Record 50 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 1 of Set
# 8         14          19        3.00          few clouds
# 9         19         100       11.86     overcast clouds
# 10        82          25        6.93    scattered clouds
# 11        91          33        3.00    scattered clouds
# 12        81          87        4.38          light rain
# 13        69          20       13.87          few clouds
# 14        74          50       15.99          light rain
# 15        82         100        3.13     overcast clouds
# 16        78          98        5.46     overcast clouds
# 17        72          40       11.41    scattered clouds
# 18        68           6        1.12           clear sky
# 19        26           1       16.11           clear sky
# 20        74          76        1.83          light rain
# 21       100          20        4.05          few clouds
# 22        86          33       12.24       moderate rain
# 23        75          77        5.01       broken clouds
# 24        66          21       16.71          light rain
# 25        74           5        6.93           clear sky
# 26        56          45       15.88    scattered clouds
# 27        88          23        1.39          light rain
# 28        92          98       19.46          light snow
# 29        20           0        4.70           clear sky
# 30       100          90       11.18          light snow
# 31        81          95        2.86     overcast clouds
# 32        76           1       13.87           clear sky
# 33        77          20        3.36          few clouds
# 34        91          99        6.55     overcast clouds
# 35        85         100        8.61          light snow
# 36        81          98        7.49          light rain
# 37        92         100       14.70     overcast clouds
# 38        93         100        2.39     overcast clouds
# 39        87          63        2.24       broken clouds
# 40        63           0        2.19           clear sky
# 41        66          48        2.51    scattered clouds
# 42        31          40        9.17    scattered clouds
# 43        75          69       12.17          light rain
# 44        88           1        6.93                mist
# 45        71           1       21.92           clear sky
# 46        82          62        5.41       broken clouds
# 47        85          95        1.36          light rain
# 48        72          99        4.61          light rain
# 49        93          75        4.70                 fog
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                        0.0                         0
# 1                        0.0                         0
# 2                        0.0                         0
# 3                        0.0                         0
# 4                        0.0                         0
# 5                        0.0                         0
# 6                        0.0                         0
# 7                        0.0                         0
# 8                        0.0                         0
# 9                        0.0                         0
# 10                       0.0                         0
# 11                       0.0                         0
# 12                       0.0                         0
# 13                       0.0                         0
# 14                       0.0                         0
# 15                       0.0                         0
# 16                       0.0                         0
# 17                       0.0                         0
# 18                       0.0                         0
# 19                       0.0                         0
# 20                       0.0                         0
# 21                       0.0                         0
# 22                       0.0                         0
# 23                       0.0                         0
# 24                       0.0                         0
# 25                       0.0                         0
# 26                       0.0                         0
# 27                       0.0                         0
# 28                       0.0                         0
# 29                       0.0                         0
# 30                       0.0                         0
# 31                       0.0                         0
# 32                       0.0                         0
# 33                       0.0                         0
# 34                       0.0                         0
# 35                       0.0                         0
# 36                       0.0                         0
# 37                       0.0                         0
# 38                       0.0                         0
# 39                       0.0                         0
# 40                       0.0                         0
# 41                       0.0                         0
# 42                       0.0                         0
# 43                       0.0                         0
# 44                       0.0                         0
# 45                       0.0                         0
# 46                       0.0                         0
# 47                       0.0                         0
# 48                       0.0                         0
# 49                       0.0                         0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Determine number of cities that have recorded rain
rain = city_data_df.loc[city_data_df["Rain inches (last 3 hrs)"]>0,"Date"].count()
#convert to string
rain_str = str(rain)
# print number cities with rain
print (" There have been " + rain_str + " cities that have recorded rainfall")
# Out:
#  There have been 7 cities that have recorded rainfall

# %%
#Determine number of cities that have recorded snowfall
snow = city_data_df.loc[city_data_df["Snow inches (last 3 hrs)"]>0,"Date"].count()
#convert to string
snow_str = str(snow)
print (" There have been " + snow_str + " cities that have recorded snow")
# Out:
#  There have been 0 cities that have recorded snow
