# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
city_data_df
# Out:
#      City_ID             City Country                 Date    Lat     Lng  \
# 0          0      Yellowknife      CA  2020-04-15 22:30:17  62.46 -114.35
# 1          1  Arraial Do Cabo      BR  2020-04-15 22:32:18 -22.97  -42.03
# 2          2     Longyearbyen      SJ  2020-04-15 22:32:18  78.22   15.64
# 3          3         Hermanus      ZA  2020-04-15 22:29:14 -34.42   19.23
# 4          4         Bagdarin      RU  2020-04-15 22:32:19  54.43  113.60
# ..       ...              ...     ...                  ...    ...     ...
# 555      555             Vila      PT  2020-04-15 22:30:28  42.03   -8.16
# 556      556          Dasoguz      TM  2020-04-15 22:30:28  41.84   59.97
# 557      557         Westport      US  2020-04-15 22:30:29  41.14  -73.36
# 558      558         Oxapampa      PE  2020-04-15 22:30:29 -10.58  -75.40
# 559      559           Sayyan      YE  2020-04-15 22:30:29  15.17   44.32
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0       30.99        63          20        2.24          few clouds
# 1       77.00        88          40        5.82    scattered clouds
# 2       33.80        74          40       27.51    scattered clouds
# 3       60.01        76          56        1.99       broken clouds
# 4       41.77        42          35        1.45    scattered clouds
# ..        ...       ...         ...         ...                 ...
# 555     57.00        93          40       10.29    scattered clouds
# 556     44.60        56           0        9.17           clear sky
# 557     54.00        21           1       11.41           clear sky
# 558     61.14        53          69        0.51          light rain
# 559     59.32        38          79        2.89          light rain
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                         0.0                         0
# 1                         0.0                         0
# 2                         0.0                         0
# 3                         0.0                         0
# 4                         0.0                         0
# ..                        ...                       ...
# 555                       0.0                         0
# 556                       0.0                         0
# 557                       0.0                         0
# 558                       0.0                         0
# 559                       0.0                         0
#
# [560 rows x 13 columns]

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
raining = str(input("Do you want it to be raining? (yes/no) "))
snowing = str(input("Do you want it to be snowing (yes/no)? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing (yes/no)? no

# %%
# Filter the dataset to find the cities that fit the criteria (and ifs for rain and snow)
if raining == 'yes' and snowing == 'yes':
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) & (city_data_df["Snow inches (last 3 hrs)"] > 0)]
elif raining =='no' and snowing == 'yes': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] == 0) & (city_data_df["Snow inches (last 3 hrs)"] > 0)]
elif raining =='yes' and snowing == 'no': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) & (city_data_df["Snow inches (last 3 hrs)"] == 0)]    
elif raining =='no' and snowing == 'no': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] == 0) & (city_data_df["Snow inches (last 3 hrs)"] == 0)]    
else:
    print("Please enter a number for min and max temps and yes/no for rain/snow")
    
preferred_cities_df.head(10)
# Out:
#     City_ID              City Country                 Date    Lat     Lng  \
# 1         1   Arraial Do Cabo      BR  2020-04-15 22:32:18 -22.97  -42.03
# 9         9          Tessalit      ML  2020-04-15 22:32:20  20.20    1.01
# 12       12          Bengkulu      ID  2020-04-15 22:32:20  -3.80  102.27
# 13       13      Vila Do Maio      CV  2020-04-15 22:28:29  15.13  -23.22
# 15       15            Harper      LR  2020-04-15 22:32:21   4.38   -7.72
# 16       16       That Phanom      TH  2020-04-15 22:32:21  16.94  104.71
# 20       20            Madang      PG  2020-04-15 22:32:22  -5.22  145.80
# 21       21            Zhuhai      CN  2020-04-15 22:32:22  22.28  113.57
# 22       22       Farafangana      MG  2020-04-15 22:32:22 -22.82   47.83
# 25       25  Puerto Escondido      MX  2020-04-15 22:32:23  15.85  -97.07
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 1      77.00        88          40        5.82    scattered clouds
# 9      83.61        19         100       11.86     overcast clouds
# 12     78.49        81          87        4.38          light rain
# 13     73.40        69          20       13.87          few clouds
# 15     80.98        82         100        3.13     overcast clouds
# 16     82.00        78          98        5.46     overcast clouds
# 20     82.87        74          76        1.83          light rain
# 21     71.01       100          20        4.05          few clouds
# 22     75.06        86          33       12.24       moderate rain
# 25     80.60        74           5        6.93           clear sky
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 1                        0.0                         0
# 9                        0.0                         0
# 12                       0.0                         0
# 13                       0.0                         0
# 15                       0.0                         0
# 16                       0.0                         0
# 20                       0.0                         0
# 21                       0.0                         0
# 22                       0.0                         0
# 25                       0.0                         0

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp","Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                 City Country  Max Temp Current Description    Lat     Lng  \
# 1    Arraial Do Cabo      BR     77.00    scattered clouds -22.97  -42.03
# 9           Tessalit      ML     83.61     overcast clouds  20.20    1.01
# 12          Bengkulu      ID     78.49          light rain  -3.80  102.27
# 13      Vila Do Maio      CV     73.40          few clouds  15.13  -23.22
# 15            Harper      LR     80.98     overcast clouds   4.38   -7.72
# 16       That Phanom      TH     82.00     overcast clouds  16.94  104.71
# 20            Madang      PG     82.87          light rain  -5.22  145.80
# 21            Zhuhai      CN     71.01          few clouds  22.28  113.57
# 22       Farafangana      MG     75.06       moderate rain -22.82   47.83
# 25  Puerto Escondido      MX     80.60           clear sky  15.85  -97.07
#
#    Hotel Name
# 1
# 9
# 12
# 13
# 15
# 16
# 20
# 21
# 22
# 25

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#                 City Country  Max Temp Current Description    Lat     Lng  \
# 1    Arraial Do Cabo      BR     77.00    scattered clouds -22.97  -42.03
# 9           Tessalit      ML     83.61     overcast clouds  20.20    1.01
# 12          Bengkulu      ID     78.49          light rain  -3.80  102.27
# 13      Vila Do Maio      CV     73.40          few clouds  15.13  -23.22
# 15            Harper      LR     80.98     overcast clouds   4.38   -7.72
# 16       That Phanom      TH     82.00     overcast clouds  16.94  104.71
# 20            Madang      PG     82.87          light rain  -5.22  145.80
# 21            Zhuhai      CN     71.01          few clouds  22.28  113.57
# 22       Farafangana      MG     75.06       moderate rain -22.82   47.83
# 25  Puerto Escondido      MX     80.60           clear sky  15.85  -97.07
#
#                                  Hotel Name
# 1                       Pousada Porto Praia
# 9
# 12                     Grage Hotel Bengkulu
# 13                    Residence 'I Delfini'
# 15                    Cape View Guest House
# 16  ณ ธาตุพนมเพลส Na That Panom Place Hotel
# 20                        Comfort Inn Hotel
# 21                                 珠海粤财假日酒店
# 22                            Austral Hotel
# 25            Aldea del Bazar Hotel and Spa

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a pop-up marker for each desired city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation_hotels.csv"
# Export the hotel_data into a CSV.
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# save figure 
fig.save("weather_data/WeatherPy_vacation_map.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7d30dc0c8502> in <module>
# ----> 1 fig.save("weather_data/WeatherPy_vacation_map.png")
#
# AttributeError: 'Figure' object has no attribute 'save'
