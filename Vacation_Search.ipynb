# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import requests
# Import the API key.
from config import g_key

# %%
#pull in g-key
gmaps.configure(api_key=g_key)

# %% [markdown]
# gmaps.configure(api_key=g_key)

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/WeatherPy_challenge.csv")
city_data_df
# Out:
#      City_ID         City Country                 Date    Lat     Lng  \
# 0          0     Westport      US  2020-04-18 19:42:22  41.14  -73.36
# 1          1       Omboue      GA  2020-04-18 19:42:23  -1.57    9.26
# 2          2      Margate      GB  2020-04-18 19:40:16  51.38    1.39
# 3          3        Kapaa      US  2020-04-18 19:42:23  22.08 -159.32
# 4          4       Duluth      US  2020-04-18 19:37:56  46.78  -92.11
# ..       ...          ...     ...                  ...    ...     ...
# 551      551   Launceston      AU  2020-04-18 19:40:41 -41.45  147.17
# 552      552  San Lawrenz      MT  2020-04-18 19:44:30  36.06   14.20
# 553      553         Mitu      CO  2020-04-18 19:44:30   1.20  -70.17
# 554      554      Rajgarh      IN  2020-04-18 19:44:30  28.63   75.38
# 555      555       Mizdah      LY  2020-04-18 19:40:46  31.45   12.98
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
raining = str(input("Do you want it to be raining? (yes/no) "))
snowing = str(input("Do you want it to be snowing (yes/no)? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 80
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing (yes/no)? no

# %%
# Filter the dataset to find the cities that fit the criteria (and ifs for rain and snow)
if raining == 'yes' and snowing == 'yes':
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) & (city_data_df["Snow inches (last 3 hrs)"] > 0)]
elif raining =='no' and snowing == 'yes': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] == 0) & (city_data_df["Snow inches (last 3 hrs)"] > 0)]
elif raining =='yes' and snowing == 'no': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) & (city_data_df["Snow inches (last 3 hrs)"] == 0)]    
elif raining =='no' and snowing == 'no': 
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] == 0) & (city_data_df["Snow inches (last 3 hrs)"] == 0)]    
else:
    print("Please enter a number for min and max temps and yes/no for rain/snow")
    
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 3         3           Kapaa      US  2020-04-18 19:42:23  22.08 -159.32
# 5         5         Rikitea      PF  2020-04-18 19:42:24 -23.12 -134.97
# 6         6  Port Elizabeth      ZA  2020-04-18 19:42:24 -33.92   25.57
# 8         8            Atar      MR  2020-04-18 19:42:25  20.52  -13.05
# 9         9     East London      ZA  2020-04-18 19:42:25 -33.02   27.91
# 13       13        Sai Buri      TH  2020-04-18 19:42:26   6.70  101.62
# 15       15   Cockburn Town      TC  2020-04-18 19:38:33  21.46  -71.14
# 17       17  Saint-Philippe      RE  2020-04-18 19:42:27 -21.36   55.77
# 19       19    Ponta Do Sol      PT  2020-04-18 19:42:27  32.67  -17.10
# 20       20        Coquimbo      CL  2020-04-18 19:42:27 -29.95  -71.34
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 3      78.80        65           1       11.41           clear sky
# ...

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp","Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 3            Kapaa      US     78.80           clear sky  22.08 -159.32
# 5          Rikitea      PF     77.11    scattered clouds -23.12 -134.97
# 6   Port Elizabeth      ZA     66.20           clear sky -33.92   25.57
# 8             Atar      MR     74.34           clear sky  20.52  -13.05
# 9      East London      ZA     71.13           clear sky -33.02   27.91
# 13        Sai Buri      TH     79.86     overcast clouds   6.70  101.62
# 15   Cockburn Town      TC     79.09       broken clouds  21.46  -71.14
# 17  Saint-Philippe      RE     77.00          few clouds -21.36   55.77
# 19    Ponta Do Sol      PT     61.00          few clouds  32.67  -17.10
# 20        Coquimbo      CL     64.40    scattered clouds -29.95  -71.34
#
#    Hotel Name
# 3
# 5
# 6
# 8
# 9
# 13
# 15
# 17
# 19
# 20

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 3            Kapaa      US     78.80           clear sky  22.08 -159.32
# 5          Rikitea      PF     77.11    scattered clouds -23.12 -134.97
# 6   Port Elizabeth      ZA     66.20           clear sky -33.92   25.57
# 8             Atar      MR     74.34           clear sky  20.52  -13.05
# 9      East London      ZA     71.13           clear sky -33.02   27.91
# 13        Sai Buri      TH     79.86     overcast clouds   6.70  101.62
# 15   Cockburn Town      TC     79.09       broken clouds  21.46  -71.14
# 17  Saint-Philippe      RE     77.00          few clouds -21.36   55.77
# 19    Ponta Do Sol      PT     61.00          few clouds  32.67  -17.10
# 20        Coquimbo      CL     64.40    scattered clouds -29.95  -71.34
#
#                                      Hotel Name
# 3        Sheraton Kauai Resort at Coconut Beach
# 5                                Pension Maro'i
# ...

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a pop-up marker for each desired city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the hotel_data into a CSV.
hotel_df.to_csv(output_data_file, index_label="City_ID")
